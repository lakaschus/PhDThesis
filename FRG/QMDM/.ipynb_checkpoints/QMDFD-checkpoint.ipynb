# %% [markdown]
# # Import libraries

# %%
import numpy as np
import time
import matplotlib
import matplotlib.pyplot as plt
from scipy import integrate
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import ode
from numpy import gradient as grad
from findiff import FinDiff, coefficients, Coefficient
from scipy import interpolate

# %% [markdown]
# # Analytic Matsubara Sum
#
# Expression for the mixed bosonic $\sigma-\Delta$ contribution

# %%
def matSum(k, ux, uxx, uy, uyy, uxy, x, y, T, mu):
  sqEpi = k**2 + 2*ux 
  sqEs = sqEpi + 4*x*uxx
  sqENG = k**2 + 2*uy
  sqEG = sqENG + 4*y*uyy
  alpha0 = 16*mu**4 - 4*mu**2*sqEG - 4*mu**2*sqENG + sqEG*sqENG - 8*mu**2*sqEs + sqEG*sqEs + sqENG*sqEs - 16*uxy**2*x*y + 0.j
  alpha1 = 2*sqEG + 2*sqENG + 2*sqEs + 0.j
  alpha2 = 3 + 0.j
  beta0 = (-4*mu**2 + sqENG)*(-4*mu**2*sqEs + sqEG*sqEs - 16*uxy**2*x*y) + 0.j
  beta1 = 16*mu**4 - 4*mu**2*(sqEG + sqENG - 2*sqEs) + sqENG*sqEs + sqEG*(sqENG + sqEs) - 16*uxy**2*x*y + 0.j
  beta2 = 8*mu**2 + sqEG + sqENG + sqEs + 0.j
  beta3 = 1 + 0.j

  var1 = ( ( 27 * ( beta0 )**( 2 ) + ( 4 * ( beta1 )**( 3 ) + ( -18 * beta0 * beta1 * beta2 + ( -1 * ( beta1 )**( 2 ) * ( beta2 )**( 2 ) + 4 * beta0 * ( beta2 )**( 3 ) ) ) ) ) )**( 1/2 )
  var2 = ( -27 * beta0 + ( 9 * beta1 * beta2 + -2 * ( beta2 )**( 3 ) ) )

  z1 = ( ( 6 )**( -1/2 ) * ( ( ( 3 * ( 3 )**( 1/2 ) * var1 + var2 ) )**( -1/3 ) * ( ( ( 6 * ( 3 )**( 1/2 ) * var1 + 2 * var2 ) )**( 2/3 ) + ( -6 * ( 2 )**( 1/3 ) * beta1 + ( -2 * ( ( 3 * ( 3 )**( 1/2 ) * var1 + var2 ) )**( 1/3 ) * beta2 + 2 * ( 2 )**( 1/3 ) * ( beta2 )**( 2 ) ) ) ) )**( 1/2 ) )
  z2 = (1/2 * ( 3 )**( -1/2 ) * ( ( ( 3 * ( 3 )**( 1/2 ) * var1 + var2 ) )**( -1/3 ) * ( complex( 0,1 ) * ( complex( 0,1 ) + ( 3 )**( 1/2 ) ) * ( ( 6 * ( 3 )**( 1/2 ) * var1 + 2 * var2 ) )**( 2/3 ) + ( 6 * ( 2 )**( 1/3 ) * ( 1 + complex( 0,1 ) * ( 3 )**( 1/2 ) ) * beta1 + ( -4 * ( ( 3 * ( 3 )**( 1/2 ) * var1 + var2 ) )**( 1/3 ) * beta2 + complex( 0,-2 ) * ( 2 )**( 1/3 ) * ( complex( 0,-1 ) + ( 3 )**( 1/2 ) ) * ( beta2 )**( 2 ) ) ) ) )**( 1/2 ))
  z3 = (1/2 * ( 3 )**( -1/2 ) * ( ( ( 3 * ( 3 )**( 1/2 ) * var1 + var2 ) )**( -1/3 ) * ( ( -1 + complex( 0,-1 ) * ( 3 )**( 1/2 ) ) * ( ( 6 * ( 3 )**( 1/2 ) * var1 + 2 * var2 ) )**( 2/3 ) + ( 6 * ( 2 )**( 1/3 ) * ( 1 + complex( 0,-1 ) * ( 3 )**( 1/2 ) ) * beta1 + ( -4 * ( ( 3 * ( 3 )**( 1/2 ) * var1 + var2 ) )**( 1/3 ) * beta2 + complex( 0,2 ) * ( 2 )**( 1/3 ) * ( complex( 0,1 ) + ( 3 )**( 1/2 ) ) * ( beta2 )**( 2 ) ) ) ) )**( 1/2 ))

  res = ( -1/2 * ( z1 )**( -1 ) * ( ( -1 * ( z1 )**( 2 ) + ( z2 )**( 2 ) ) )**( -1 ) * ( ( -1 * ( z1 )**( 2 ) + ( z3 )**( 2 ) ) )**( -1 ) * ( alpha0 + ( ( z1 )**( 2 ) * alpha1 + ( z1 )**( 4 ) * alpha2 ) ) * 
         1./np.tan( 1/2 * ( T )**( -1 ) * z1 ) + ( -1/2 * ( z2 )**( -1 ) * ( ( ( z1 )**( 2 ) + -1 * ( z2 )**( 2 ) ) )**( -1 ) * ( ( -1 * ( z2 )**( 2 ) + ( z3 )**( 2 ) ) )**( -1 ) * ( alpha0 + ( ( z2 )**( 2 ) * alpha1 + ( z2 )**( 4 ) * alpha2 ) ) * 1./np.tan( 1/2 * ( T )**( -1 ) * z2 ) + -1/2 * ( z3 )**( -1 ) * ( ( ( z1 )**( 2 ) + -1 * ( z3 )**( 2 ) ) )**( -1 ) * ( ( ( z2 )**( 2 ) + -1 * ( z3 )**( 2 ) ) )**( -1 ) * ( alpha0 + ( ( z3 )**( 2 ) * alpha1 + ( z3 )**( 4 ) * alpha2 ) ) * 1./np.tan( 1/2 * ( T )**( -1 ) * z3 ) ) )
  
  return np.real(res) # This quantity is real, but numerically contains a very small imaginary part

# %% [markdown]
# # Energy Functions

# %%
def Epion(ux, k):
  return np.sqrt(k**2 + 2*ux)

def Esig(x, ux, uxx, k):
  return np.sqrt(k**2 + 2*ux + 4*x*uxx)

def Eq(x, k):
  return np.sqrt(k**2 + hx**2*x) 

def Epsi(x, y, k, mu, n):
  return np.sqrt(hy**2*y + ( Eq(x, k) + (-1)**n*mu )**2)

def ENG(uy, k):
  return np.sqrt(k**2 + 2*uy)

# %% [markdown]
# # Plot Function

# %%
def plot(u, xgrd, ygrd):
  fig = plt.figure(figsize=(20,10)) 
  ax = fig.gca(projection='3d')  
  ax.plot_wireframe(np.sqrt(xgrd), np.sqrt(ygrd), u)
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  #ax.view_init(45, 0)
  plt.show()

# %% [markdown]
# # Solver Routines

# %%
def dudk(u, k, T, mu):
  global k_print
  # converts vector to 2D array:
  u = u.reshape(-1, Nx) 

  # Finite differences:
  ux, uy = d_dx(u), d_dy(u)
  uxx, uyy = d2_dx2(u), d2_dy2(u)
  uxy = d2_dxdy(u)

  Ep = Epion(ux, k)
  Es = Esig(x, ux, uxx, k)
  Eng = ENG(uy, k)
  Eps = Eq(xgrd, k)
  Ek1 = Epsi(xgrd, ygrd, k, mu, 1)
  Ek2 = Epsi(xgrd, ygrd, k, mu, 0)
  dudk = k**4/(12*np.pi**2)*(3.0/Ep*(1.0/np.tanh(Ep/(2*T))) + 2/Eng*(2*np.sinh(Eng/T))/(np.cosh(Eng/T) - np.cosh((2*mu)/T))
                          - 8/Ek1*(1 - mu/Eps)*np.tanh(Ek1/(2*T)) - 8/Ek2*(1 + mu/Eps)*np.tanh(Ek2/(2*T))
                          - 4*(1/Eps*(np.tanh((Eps - mu)/(2*T)) + np.tanh((Eps + mu)/(2*T))))
                          + 2*matSum(k, ux, uxx, uy, uyy, uxy, xgrd, ygrd, T, mu) )

  if k <= k_print:
      print("\n")
      print("flow scale: ", k)
      k_print -= 50

  return np.squeeze(dudk).flatten() # squeeze converts 2D array to vector
  
def f(k, u, T, mu):
    return dudk(u, k, T, mu)

def solver(T, mu, params):
    ode_order = 5
    nsteps = 20000
    ode_integrator = 'vode'#'lsoda'
    ode_method = 'bdf'#'adams'
    r_tol = 1e-11
    a_tol = 1e-11
    ode15s = ode(f)
    ode15s.set_integrator(ode_integrator, method=ode_method, order=ode_order, nsteps = nsteps, rtol=r_tol, atol=a_tol)
    u0_vec = np.squeeze(np.asarray(v0(xgrd, ygrd, params))).flatten()
    r = ode15s.set_initial_value(u0_vec, k[0]).set_f_params(T, mu)
    c = 1
    while c < N_k:
        #print(ode15s.t)
        ode15s.integrate(ode15s.t-dk)
        c += 1
        if ode15s.successful() == False:                                                            
            print("!Solver NOT successful!")   
    return ode15s

# %% [markdown]
# # Parameters

# %%
def v0(X, Y, params):
    # Initial potential
    cutoff, lamx, v, mx, hx, c, lamy, lamxy, my, hy = params
    return 1/2*mx**2*X + lamx/4*(X - v**2)**2 + 1/2*my**2*Y + lamy/4*(Y - vy**2)**2 + lamxy/4*(X*Y)
  
cutoff = 1000
cutoff, lamx, v, mx, hx, c, lamy, lamxy, my, hy =  1000, 0.001, 0, 969, 4.2, 1750000, 8, -0.6, 900, 3
v, vy = 0, 0
params = [cutoff, lamx, v, mx, hx, c, lamy, lamxy, my, hy]
L = 180**2
L2 = 180**2

Nx = 50
x = np.linspace(0, L, Nx)

Ny = 50
y = np.linspace(0, L2, Ny)

dx = np.abs(x[1] - x[0])
dy = np.abs(y[1] - y[0])

acc = 2
d_dx = FinDiff(1, dx, 1, acc = acc)
d2_dx2 = FinDiff(1, dx, 2, acc = acc)
d_dy = FinDiff(0, dy, 1, acc = acc)
d2_dy2 = FinDiff(0, dy, 2, acc = acc)

d2_dxdy = FinDiff((0, dy), (1, dx), acc = acc)

xgrd, ygrd = np.meshgrid(x, y)

N_k = 50
k_IR = 100
k = np.linspace(cutoff, k_IR, N_k) # DEFINE TIME HERE ################################################################################
dk = k[0] - k[1]

# %% [markdown]
# # Solve

# %%
start = time.time()  

print("UV potential: ")
plot(v0(xgrd, ygrd, params), xgrd, ygrd)

TV, muV = 25, 310 # (T, mu)
expl = c*np.sqrt(xgrd) + 2*muV**2*ygrd
k_print = cutoff
sol = solver(TV, muV, params) # START HERE ##################################
s = sol.y.reshape(-1, Nx)
print("TOTAL TIME: ", time.time()-start)
# Out:
# UV potential:
# flow scale:  1000.0
#
#
# flow scale:  949.7477203775126
#
#
# flow scale:  899.9041262051455
#
#
# flow scale:  849.4660833282219
#
#
# flow scale:  799.7728637529498
#
#
# flow scale:  749.4318304213597
#
#
# flow scale:  699.4392438494805
#
#
# flow scale:  649.4486245012689
#
#
# flow scale:  598.7238563546467
#
#
# flow scale:  548.8199547911549
#
#
# flow scale:  499.50246862439786
#
#
# flow scale:  447.93964503816136
#
#
# flow scale:  399.2414227622713
#
#
# flow scale:  348.5015224329414
#
#
# flow scale:  298.3583559093027
#
#
# flow scale:  249.99792433329128
#
#
# flow scale:  199.736276034053
#
#
# flow scale:  149.34966311000704
#
#
# flow scale:  99.82716518549782
# TOTAL TIME:  11.896511316299438

# %% [markdown]
# Minimum:

# %%
argm = np.unravel_index(np.argmin(s - expl, axis=None), s.shape)
fpi = np.sqrt(argm[1]*dx)
diq = np.sqrt(argm[0]*dy)
print("argmin: ", argm)
print("fpi: ", fpi)
print("diq: ", diq)
# Out:
# argmin:  (3, 1)
# fpi:  25.71428571428571
# diq:  44.53844933748542

# %% [markdown]
# # Interpolation

# %%
xnew = np.linspace(0, L, 8*Nx)
ynew = np.linspace(0, L2, 8*Ny)
dx_new, dy_new = xnew[1] - xnew[0], ynew[1] - ynew[0]
xgrd_new, ygrd_new = np.meshgrid(xnew, ynew)

expl_new = c*np.sqrt(xgrd_new) + 2*muV**2*ygrd_new

u_interp = interpolate.interp2d(x, y, s, kind='cubic')
s_new = u_interp(xnew, ynew)
argm = np.unravel_index(np.argmin(s_new - expl_new, axis=None), s_new.shape)
fpi = np.sqrt(argm[1]*dx_new)
diq = np.sqrt(argm[0]*dy_new)
print("argmin: ", argm)
print("fpi: ", fpi)
print("diq: ", diq)
# Out:
# argmin:  (28, 7)
# fpi:  23.84158242717079
# diq:  47.68316485434158
